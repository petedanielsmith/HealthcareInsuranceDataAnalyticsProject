# %% [markdown]
# # Health Insurance Project: Data Import, Clean & Transform
# ---

# %% [markdown]
# Import Pandas library:

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ---
#
# ## Import and check the data
#
# Import the insurance_raw.csv file:

# %%
insurance_raw = pd.read_csv("../data/insurance_raw.csv")

# %% [markdown]
# View the first 10 rows of the raw file:

# %%
insurance_raw.head(10)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160
# 6   46  female  33.440         1     no  southeast   8240.58960
# 7   37  female  27.740         3     no  northwest   7281.50560
# 8   37    male  29.830         2     no  northeast   6406.41070
# 9   60  female  25.840         0     no  northwest  28923.13692

# %% [markdown]
# Check summary of inital raw data:

# %%
before_summary = pd.DataFrame({
    "dtype": insurance_raw.dtypes,
    "missing_values": insurance_raw.isnull().sum(),
    "non_missing": insurance_raw.notnull().sum(),
    "unique_values": insurance_raw.nunique()
})
before_summary
# Out:
#             dtype  missing_values  non_missing  unique_values
# age         int64               0         1338             47
# sex        object               0         1338              2
# bmi       float64               0         1338            548
# children    int64               0         1338              6
# smoker     object               0         1338              2
# region     object               0         1338              4
# charges   float64               0         1338           1337

# %% [markdown]
# There are no missing values, so no need to handle any missing data.
#
# Age and bmi have very varied results, looking at the unique values, so I will look to add new bin/banding groups for both of them.
#
# Sex, smoker and region have very few unique values so look like category columns. I will view the unique values and set them as category columns.
#
# Children i will leave as an integer, but will add a new column to flag if it includes family plan.

# %% [markdown]
# ---
#
# ## Rename columns
#
# Make a copy of the DataFrame to work with:

# %%
insurance = insurance_raw.copy()

# %% [markdown]
# Remove duplicates (only 1 row so deleting it):

# %%
insurance.drop_duplicates(inplace=True)

# %% [markdown]
# Rename all the column names to title case:

# %%
insurance.columns = [col.title() for col in insurance.columns]

# %% [markdown]
# Change the Bmi column name to be BMI all capitals:

# %%
insurance.rename(columns={'Bmi': 'BMI'}, inplace=True)

# %% [markdown]
# Display the updated column names:

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1337 non-null   int64
#  1   Sex       1337 non-null   object
#  2   BMI       1337 non-null   float64
#  3   Children  1337 non-null   int64
#  4   Smoker    1337 non-null   object
#  5   Region    1337 non-null   object
#  6   Charges   1337 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 83.6+ KB

# %% [markdown]
# ---
#
# ## Address categorical columns
#
# View the unique values in each of the columns that will be categories:

# %%
categorical_columns = ['Sex', 'Smoker', 'Region']

for col in categorical_columns:
    print(f"Unique values in {col} are : {insurance[col].unique()}")
# Out:
# Unique values in Sex are : ['female' 'male']
# Unique values in Smoker are : ['yes' 'no']
# Unique values in Region are : ['southwest' 'southeast' 'northwest' 'northeast']

# %% [markdown]
# Set these to be category data type:

# %%
categorical_columns = ['Sex', 'Smoker', 'Region']

for col in categorical_columns:
    insurance[col] = insurance[col].astype('category')

# %% [markdown]
# And view the updated column types:

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       1337 non-null   int64
#  1   Sex       1337 non-null   category
#  2   BMI       1337 non-null   float64
#  3   Children  1337 non-null   int64
#  4   Smoker    1337 non-null   category
#  5   Region    1337 non-null   category
#  6   Charges   1337 non-null   float64
# dtypes: category(3), float64(2), int64(2)
# memory usage: 56.6 KB

# %% [markdown]
# ---
#
# ## Add Age Groups
#
# Googling US Health Insurance age brackets, there isn't a defined range that is in place.
#
# After viewing [KFF Site](https://www.kff.org/affordable-care-act/state-indicator/marketplace-plan-selection-by-age/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D) and [State Health Compare Site](https://statehealthcompare.shadac.org/table/4/health-insurance-coverage-type-by-age#1/5,4,1,10,86,9,8,6,3,12,13,20,25,14,21,22,23,24,11/76/7,8), i have decided to go with these age groups as the age range is 18-64:
#
# - `< 26` - 'Ages 18-25'
# - `>= 26 < 35` - 'Ages 26-34'
# - `>= 35 < 45` - 'Ages 35-44'
# - `>= 44 < 55` - 'Ages 44-54'
# - `>= 55` - 'Ages 55 and over'

# %%
insurance['Age_Group'] = pd.cut(
    insurance['Age'],
    bins=[17, 26, 35, 45, 55, 100],
    labels=['Ages 18-25', 'Ages 26-34', 'Ages 35-44', 'Ages 45-54', 'Ages 55 and over'],
    right=False
)

insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group
# 0   19  female  27.900         0    yes  southwest  16884.92400  Ages 18-25
# 1   18    male  33.770         1     no  southeast   1725.55230  Ages 18-25
# 2   28    male  33.000         3     no  southeast   4449.46200  Ages 26-34
# 3   33    male  22.705         0     no  northwest  21984.47061  Ages 26-34
# 4   32    male  28.880         0     no  northwest   3866.85520  Ages 26-34

# %% [markdown]
# ---
#
# ## Add BMI Groups
#
# On the [NHS Site](https://www.nhs.uk/conditions/obesity/) it defines the BMI groups to be:
#
# - `below 18.5` – you're in the underweight range
# - `18.5 to 24.9` – you're in the healthy weight range
# - `25 to 29.9` – you're in the overweight range
# - `30 to 39.9` – you're in the obese range
# - `40 or above` – you're in the severely obese range
#
# So will set my BMI_Group to be:
#
# - `< 18.5` - 'Underweight'
# - `>= 18.5 < 25` - 'Healthy Weight'
# - `>= 25 < 30` - 'Overweight'
# - `>= 30 < 40` - 'Obese'
# - `>= 40` - 'Severely Obese'

# %%
insurance['BMI_Group'] = pd.cut(
    insurance['BMI'],
    bins=[0, 18.5, 25, 30, 40, 100],
    labels=['Underweight', 'Healthy Weight', 'Overweight', 'Obese', 'Severely Obese'],
    right=False
)

insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group  \
# 0   19  female  27.900         0    yes  southwest  16884.92400  Ages 18-25
# 1   18    male  33.770         1     no  southeast   1725.55230  Ages 18-25
# 2   28    male  33.000         3     no  southeast   4449.46200  Ages 26-34
# 3   33    male  22.705         0     no  northwest  21984.47061  Ages 26-34
# 4   32    male  28.880         0     no  northwest   3866.85520  Ages 26-34
#
#         BMI_Group
# 0      Overweight
# 1           Obese
# 2           Obese
# 3  Healthy Weight
# 4      Overweight

# %% [markdown]
# ---
#
# ## Add Plan column
#
# I will add a new Plan column that will be Family if Children is > 0 or Standard if its just individual with no children and make a category column

# %%
insurance['Plan'] = np.where(insurance['Children'] > 0, 'Family', 'Standard')
insurance['Plan'] = insurance['Plan'].astype('category')
insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group  \
# 0   19  female  27.900         0    yes  southwest  16884.92400  Ages 18-25
# 1   18    male  33.770         1     no  southeast   1725.55230  Ages 18-25
# 2   28    male  33.000         3     no  southeast   4449.46200  Ages 26-34
# 3   33    male  22.705         0     no  northwest  21984.47061  Ages 26-34
# 4   32    male  28.880         0     no  northwest   3866.85520  Ages 26-34
#
#         BMI_Group      Plan
# 0      Overweight  Standard
# 1           Obese    Family
# 2           Obese    Family
# 3  Healthy Weight  Standard
# 4      Overweight  Standard

# %% [markdown]
# ---
#
# ## Title case existing category values
#
# Change the category values for Sex, Smoker and Regio so all the values have a capital first letter

# %%
insurance['Sex'] = insurance['Sex'].cat.rename_categories(lambda x: x.title())
insurance['Smoker'] = insurance['Smoker'].cat.rename_categories(lambda x: x.title())
insurance['Region'] = insurance['Region'].cat.rename_categories(lambda x: x.title())
insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group  \
# 0   19  Female  27.900         0    Yes  Southwest  16884.92400  Ages 18-25
# 1   18    Male  33.770         1     No  Southeast   1725.55230  Ages 18-25
# 2   28    Male  33.000         3     No  Southeast   4449.46200  Ages 26-34
# 3   33    Male  22.705         0     No  Northwest  21984.47061  Ages 26-34
# 4   32    Male  28.880         0     No  Northwest   3866.85520  Ages 26-34
#
#         BMI_Group      Plan
# 0      Overweight  Standard
# 1           Obese    Family
# 2           Obese    Family
# 3  Healthy Weight  Standard
# 4      Overweight  Standard

# %% [markdown]
# ---
#
# ## Add charges per person column
#
# I am adding a column that is the charges divided by the number of people included (Children + 1) to get a cost per person, which i may or may not use in my investigation

# %%
insurance['Charges_Per_Person'] = insurance['Charges'] / (insurance['Children'] + 1)
insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group  \
# 0   19  Female  27.900         0    Yes  Southwest  16884.92400  Ages 18-25
# 1   18    Male  33.770         1     No  Southeast   1725.55230  Ages 18-25
# 2   28    Male  33.000         3     No  Southeast   4449.46200  Ages 26-34
# 3   33    Male  22.705         0     No  Northwest  21984.47061  Ages 26-34
# 4   32    Male  28.880         0     No  Northwest   3866.85520  Ages 26-34
#
#         BMI_Group      Plan  Charges_Per_Person
# 0      Overweight  Standard         16884.92400
# 1           Obese    Family           862.77615
# 2           Obese    Family          1112.36550
# 3  Healthy Weight  Standard         21984.47061
# 4      Overweight  Standard          3866.85520

# %% [markdown]
# ---
#
# ## Add outlier columns
#
# Create a function to see if a charge or charge_per_person is an outlier and falls outside 1.5 * IQR
#
# Use the function to add a new column that sets true or false as its value depending if it is an outlier

# %%
def check_outlier(s):
    """ Calculating inter quartile range and returning True or False"""
    q1, q3 = s.quantile([0.25, 0.75])
    iqr = q3 - q1
    low, high = q1 - 1.5*iqr, q3 + 1.5*iqr
    return (s < low) | (s > high)

insurance['Charges_Outlier'] = check_outlier(insurance['Charges'])
insurance['Charges_Per_Person_Outlier'] = check_outlier(insurance['Charges_Per_Person'])
insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group  \
# 0   19  Female  27.900         0    Yes  Southwest  16884.92400  Ages 18-25
# 1   18    Male  33.770         1     No  Southeast   1725.55230  Ages 18-25
# 2   28    Male  33.000         3     No  Southeast   4449.46200  Ages 26-34
# 3   33    Male  22.705         0     No  Northwest  21984.47061  Ages 26-34
# 4   32    Male  28.880         0     No  Northwest   3866.85520  Ages 26-34
#
#         BMI_Group      Plan  Charges_Per_Person  Charges_Outlier  \
# 0      Overweight  Standard         16884.92400            False
# 1           Obese    Family           862.77615            False
# 2           Obese    Family          1112.36550            False
# 3  Healthy Weight  Standard         21984.47061            False
# 4      Overweight  Standard          3866.85520            False
#
#    Charges_Per_Person_Outlier
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %% [markdown]
# ---
#
# ## Add numeric columns for categories
#
# So that I can include the category columns in correlation checks, i will add a numeric equivalent column for each of the categories and set the value as the category code

# %%
cat_cols = ['Sex', 'Smoker', 'Region', 'Plan', 'BMI_Group', 'Age_Group']
for col in cat_cols:
    insurance[f"{col}_num"] = insurance[col].cat.codes

insurance.head()
# Out:
#    Age     Sex     BMI  Children Smoker     Region      Charges   Age_Group  \
# 0   19  Female  27.900         0    Yes  Southwest  16884.92400  Ages 18-25
# 1   18    Male  33.770         1     No  Southeast   1725.55230  Ages 18-25
# 2   28    Male  33.000         3     No  Southeast   4449.46200  Ages 26-34
# 3   33    Male  22.705         0     No  Northwest  21984.47061  Ages 26-34
# 4   32    Male  28.880         0     No  Northwest   3866.85520  Ages 26-34
#
#         BMI_Group      Plan  Charges_Per_Person  Charges_Outlier  \
# 0      Overweight  Standard         16884.92400            False
# 1           Obese    Family           862.77615            False
# 2           Obese    Family          1112.36550            False
# 3  Healthy Weight  Standard         21984.47061            False
# 4      Overweight  Standard          3866.85520            False
#
#    Charges_Per_Person_Outlier  Sex_num  Smoker_num  Region_num  Plan_num  \
# 0                       False        0           1           3         1
# 1                       False        1           0           2         0
# 2                       False        1           0           2         0
# 3                       False        1           0           1         1
# 4                       False        1           0           1         1
#
#    BMI_Group_num  Age_Group_num
# 0              2              0
# 1              3              0
# 2              3              1
# 3              1              1
# 4              2              1

# %% [markdown]
# ---
#
# ## Reorder the columns
#
# Just for neatness, reorder the columns so that like columns appear next to each other for ease of viewing the data

# %%
insurance = insurance[[
    'Age', 'Age_Group', 'Age_Group_num',
    'Sex', 'Sex_num',
    'BMI', 'BMI_Group', 'BMI_Group_num',
    'Children', 'Plan', 'Plan_num',
    'Smoker', 'Smoker_num',
    'Region', 'Region_num',
    'Charges', 'Charges_Per_Person',
    'Charges_Outlier', 'Charges_Per_Person_Outlier'
]]
insurance.head()
# Out:
#    Age   Age_Group  Age_Group_num     Sex  Sex_num     BMI       BMI_Group  \
# 0   19  Ages 18-25              0  Female        0  27.900      Overweight
# 1   18  Ages 18-25              0    Male        1  33.770           Obese
# 2   28  Ages 26-34              1    Male        1  33.000           Obese
# 3   33  Ages 26-34              1    Male        1  22.705  Healthy Weight
# 4   32  Ages 26-34              1    Male        1  28.880      Overweight
#
#    BMI_Group_num  Children      Plan  Plan_num Smoker  Smoker_num     Region  \
# 0              2         0  Standard         1    Yes           1  Southwest
# 1              3         1    Family         0     No           0  Southeast
# 2              3         3    Family         0     No           0  Southeast
# 3              1         0  Standard         1     No           0  Northwest
# 4              2         0  Standard         1     No           0  Northwest
#
#    Region_num      Charges  Charges_Per_Person  Charges_Outlier  \
# 0           3  16884.92400         16884.92400            False
# 1           2   1725.55230           862.77615            False
# 2           2   4449.46200          1112.36550            False
# 3           1  21984.47061         21984.47061            False
# 4           1   3866.85520          3866.85520            False
#
#    Charges_Per_Person_Outlier
# 0                       False
# 1                       False
# 2                       False
# 3                       False
# 4                       False

# %% [markdown]
# ---
#
# ## Compare before and after summaries
#
# Create an after summary:

# %%
after_summary = pd.DataFrame({
    "dtype": insurance.dtypes,
    "missing_values": insurance.isnull().sum(),
    "non_missing": insurance.notnull().sum(),
    "unique_values": insurance.nunique()
})

# %% [markdown]
# View before summary again:

# %%
before_summary
# Out:
#             dtype  missing_values  non_missing  unique_values
# age         int64               0         1338             47
# sex        object               0         1338              2
# bmi       float64               0         1338            548
# children    int64               0         1338              6
# smoker     object               0         1338              2
# region     object               0         1338              4
# charges   float64               0         1338           1337

# %% [markdown]
# View after summary:

# %%
after_summary
# Out:
#                                dtype  missing_values  non_missing  \
# Age                            int64               0         1337
# Age_Group                   category               0         1337
# Age_Group_num                   int8               0         1337
# Sex                         category               0         1337
# Sex_num                         int8               0         1337
# BMI                          float64               0         1337
# BMI_Group                   category               0         1337
# BMI_Group_num                   int8               0         1337
# Children                       int64               0         1337
# Plan                        category               0         1337
# Plan_num                        int8               0         1337
# Smoker                      category               0         1337
# Smoker_num                      int8               0         1337
# Region                      category               0         1337
# Region_num                      int8               0         1337
# Charges                      float64               0         1337
# Charges_Per_Person           float64               0         1337
# Charges_Outlier                 bool               0         1337
# Charges_Per_Person_Outlier      bool               0         1337
#
#                             unique_values
# Age                                    47
# Age_Group                               5
# Age_Group_num                           5
# Sex                                     2
# Sex_num                                 2
# BMI                                   548
# BMI_Group                               5
# BMI_Group_num                           5
# Children                                6
# Plan                                    2
# Plan_num                                2
# Smoker                                  2
# Smoker_num                              2
# Region                                  4
# Region_num                              4
# Charges                              1337
# Charges_Per_Person                   1337
# Charges_Outlier                         2
# Charges_Per_Person_Outlier              2

# %% [markdown]
# You can see a lot more columns added now and all with the correct data types
#
# View the describe summary of the cleaned table:

# %%
insurance.describe(include='all').T
# Out:
#                              count unique         top  freq          mean  \
# Age                         1337.0    NaN         NaN   NaN     39.222139
# Age_Group                     1337      5  Ages 18-25   305           NaN
# Age_Group_num               1337.0    NaN         NaN   NaN      1.938669
# Sex                           1337      2        Male   675           NaN
# Sex_num                     1337.0    NaN         NaN   NaN      0.504862
# BMI                         1337.0    NaN         NaN   NaN     30.663452
# BMI_Group                     1337      5       Obese   615           NaN
# BMI_Group_num               1337.0    NaN         NaN   NaN      2.397906
# Children                    1337.0    NaN         NaN   NaN      1.095737
# Plan                          1337      2      Family   764           NaN
# Plan_num                    1337.0    NaN         NaN   NaN      0.428571
# Smoker                        1337      2          No  1063           NaN
# Smoker_num                  1337.0    NaN         NaN   NaN      0.204936
# Region                        1337      4   Southeast   364           NaN
# Region_num                  1337.0    NaN         NaN   NaN      1.516081
# Charges                     1337.0    NaN         NaN   NaN  13279.121487
# Charges_Per_Person          1337.0    NaN         NaN   NaN   8274.549739
# Charges_Outlier               1337      2       False  1198           NaN
# Charges_Per_Person_Outlier    1337      2       False  1255           NaN
#
#                                      std         min         25%         50%  \
# Age                            14.044333        18.0        27.0        39.0
# Age_Group                            NaN         NaN         NaN         NaN
# Age_Group_num                   1.425015         0.0         1.0         2.0
# Sex                                  NaN         NaN         NaN         NaN
# Sex_num                         0.500163         0.0         0.0         1.0
# BMI                             6.100468       15.96       26.29        30.4
# BMI_Group                            NaN         NaN         NaN         NaN
# BMI_Group_num                   0.895896         0.0         2.0         3.0
# Children                        1.205571         0.0         0.0         1.0
# Plan                                 NaN         NaN         NaN         NaN
# Plan_num                        0.495057         0.0         0.0         0.0
# Smoker                               NaN         NaN         NaN         NaN
# Smoker_num                      0.403806         0.0         0.0         0.0
# Region                               NaN         NaN         NaN         NaN
# Region_num                      1.105208         0.0         1.0         2.0
# Charges                     12110.359656   1121.8739    4746.344   9386.1613
# Charges_Per_Person           9400.669995  768.000733  2206.73234  4320.41085
# Charges_Outlier                      NaN         NaN         NaN         NaN
# Charges_Per_Person_Outlier           NaN         NaN         NaN         NaN
#
#                                     75%          max
# Age                                51.0         64.0
# Age_Group                           NaN          NaN
# Age_Group_num                       3.0          4.0
# Sex                                 NaN          NaN
# Sex_num                             1.0          1.0
# BMI                                34.7        53.13
# BMI_Group                           NaN          NaN
# BMI_Group_num                       3.0          4.0
# Children                            2.0          5.0
# Plan                                NaN          NaN
# Plan_num                            1.0          1.0
# Smoker                              NaN          NaN
# Smoker_num                          0.0          1.0
# Region                              NaN          NaN
# Region_num                          2.0          3.0
# Charges                     16657.71745  63770.42801
# Charges_Per_Person             11455.28  63770.42801
# Charges_Outlier                     NaN          NaN
# Charges_Per_Person_Outlier          NaN          NaN

# %% [markdown]
# ---
#
# ## Save the clean data to a new file
#
# Now the data is cleaned, save this to a new csv file with the _cleaned suffix. This file can then be used as the starting point in the visualisation notebook.

# %%
insurance.to_csv("../data/insurance_cleaned.csv", index=False)
